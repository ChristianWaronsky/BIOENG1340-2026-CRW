# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !cp "/gdrive/MyDrive/BIOENG 1340 2340 Fall2021/TEST/BIOENG 1340 2340 Fall2022/Week01/Week01/pigdicom.zip" .

# %%
# !mkdir pigdicom

# %%
# !unzip pigdicom.zip
# Out:
# Archive:  pigdicom.zip
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319074561753595406.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319074645879295410.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319074716039095414.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319074791125395418.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319074866856595422.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319074945827895426.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319075020696895430.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.20130403190751299695434.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319075171412895438.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319075254145995442.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319075327640995446.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.201304031907548287695450.dcm
#   inflating: 1.3.12.2.1107.5.2.31.30831.2013040319075483096095454.dcm
# ...

# %%
! mv *.dcm pigdicom

# %%
! pip install simpleitk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 52.8 MB 215 kB/s
# ...

# %%
import SimpleITK as sitk

# %%
import SimpleITK as sitk
imagePath = '/content/pigdicom/'

print("Reading Dicom directory:", imagePath)
reader = sitk.ImageSeriesReader()

dicom_names = reader.GetGDCMSeriesFileNames(imagePath)
reader.SetFileNames(dicom_names)

image = reader.Execute()
# Out:
# Reading Dicom directory: /content/pigdicom/

# %%
image.GetSize()
# Out:
# (256, 192, 51)

# %%
image.GetSpacing()
# Out:
# (1.5, 1.5, 4.5)

# %%
image.GetPixelIDTypeAsString()
# Out:
# '16-bit unsigned integer'
